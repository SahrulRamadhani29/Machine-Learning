# %% [markdown]
# # JS01: Tugas Lab 1

# %% [markdown]
# ## Bagian 1
#
# pip

# %%
import os

os.environ['SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL'] = 'True'
# !pip install -q pyprep scipy wandb scikit-learn pyECG

# %% [markdown]
# ### Kegunaan library
#
# * PyPREP dipakai untuk menyiapkan data EEG, termasuk mendeteksi kanal yang bermasalah dan melakukan referensi ulang.
# * SciPy menyediakan fungsi komputasi ilmiah, seperti statistik, optimasi, integrasi, dan pemrosesan sinyal.
# * Weights & Biases (wandb) mencatat eksperimen, metrik, konfigurasi, dan artefak model.
# * pyECG membantu membaca dan mengolah sinyal elektrokardiogram (ECG).

# %% [markdown]
# ## Bagian 2
#
# ### Contoh pelanggaran etika dan hukum
#
# Salah satu contohnya adalah membuat suara atau video deepfake seseorang untuk penipuan tanpa persetujuan pemilik identitas. Tindakan ini memakai data pribadi orang lain dan dapat merugikan korban. Di Indonesia, pemrosesan data pribadi diatur dalam UU Nomor 27 Tahun 2022 tentang Pelindungan Data Pribadi. Jika konten tersebut digunakan untuk manipulasi atau penipuan melalui sistem elektronik, ketentuan dalam UU ITE juga dapat berlaku.
#
# Referensi:
#
# 1. https://peraturan.bpk.go.id/Details/229798/uu-no-27-tahun-2022
# 2. https://peraturan.bpk.go.id/Details/274494/uu-no-1-tahun-2024
#
# ### Dampak energi dan lingkungan
#
# Pelatihan dan penggunaan model AI membutuhkan pusat data yang memakai listrik serta air untuk pendinginan. Dampaknya bergantung pada ukuran model, jumlah penggunaan, efisiensi perangkat, dan sumber listrik. Menurut saya, dampaknya dapat dikurangi dengan memilih model yang sesuai kebutuhan, memakai model yang lebih kecil untuk tugas sederhana, menjalankan komputasi pada pusat data yang efisien, dan meningkatkan penggunaan energi rendah emisi.
#
# Referensi:
#
# 1. https://www.iea.org/reports/electricity-2024
# 2. https://sustainability.google/reports/
