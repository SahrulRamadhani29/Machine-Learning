# %% [markdown]
# # JS02: Lab 2
#
# Pra Pengolahan Data: Data Terstruktur

# %% [markdown]
# ## Persiapan data

# %%
from pathlib import Path
from urllib.request import Request, urlopen

data_path = Path('Titanic-Dataset.csv')
if not data_path.exists():
    request = Request(
        'https://1812311909-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2FYHOv2XH8FJMJSMsnhwNa%2Fuploads%2F7zKWw3qIZeyAncxPCMdv%2FTitanic-Dataset.csv?alt=media&token=bfd31564-1266-46eb-a7bc-56439f4317c1',
        headers={'User-Agent': 'Mozilla/5.0'}
    )
    data_path.write_bytes(urlopen(request).read())

# %% [markdown]
# ## Langkah 0: Persiapan
#
# import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Langkah 1: Memuat Data
#
# read_csv, head

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# Tampilkan 5 data teratas
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Langkah 2: Inspeksi Data
#
# info, isnull, sum

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# ...

# %% [markdown]
# ## Langkah 3: Data Imputation
#
# fillna

# %%
# Age menggunakan mean
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Cabin menggunakan "DECK"
df['Cabin'] = df['Cabin'].fillna("DECK")

# Embarked menggunakan modus
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %% [markdown]
# ## Langkah 4: Validasi Hasil
#
# info, head

# %%
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    str
#  11  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %% [markdown]
# ## (Opsional) Simpan Hasil
#
# to_csv

# %%
df.to_csv('Titanic-Dataset-Fixed.csv', index=False)
